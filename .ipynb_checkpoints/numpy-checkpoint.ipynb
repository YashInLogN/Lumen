# %%
import numpy as np
import pandas as pd

data = np.random.rand(10, 5)
# data = data+50
data = data+data.mean()
df = pd.DataFrame(data, columns=['first', 'second', 'third', 'fourth', 'fifth'])
print(df.head())
# Out:
#       first    second     third    fourth     fifth
# 0  0.621526  1.229904  0.543473  0.928720  1.229150
# 1  0.922692  1.222086  0.745474  0.706752  1.390201
# 2  1.062514  0.676620  1.178337  0.795373  1.216982
# 3  0.740489  0.934876  1.304565  1.293081  1.395336
# 4  0.758649  0.534705  0.971278  0.889868  1.078664

# %%
check = np.array([[1, 2, 5.5], [6, 7, 9.5]])
check = check.astype(int)
print(check.sum())
# Out:
# 30

# %%
arr = np.arange(1, 11, 1)
print(arr[0: 6])
# Out:
# [1 2 3 4 5 6]
